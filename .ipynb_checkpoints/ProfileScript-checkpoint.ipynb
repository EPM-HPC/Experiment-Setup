# %%
#!/usr/bin/python3
import sys
import subprocess
import os
import time
import re


# enter dir
class cd:
    """Context manager for changing the current working directory"""
    def __init__(self, newPath):
        self.newPath = os.path.expanduser(newPath)

    def __enter__(self):
        self.savedPath = os.getcwd()
        os.chdir(self.newPath)

    def __exit__(self, etype, value, traceback):
        os.chdir(self.savedPath)
#============================================================================================================
# make the kernel run multipul times
#============================================================================================================
def copy_cuda_kernels():
    # the first job should copy the kernel for multipule times using wrapper_kernel_begin/end
    current_files = subprocess.check_output(['ls']).decode('utf-8').split('\n')
    
    changed_file = False
    generate_new_file = False
    
    
    for file in current_files:
        ori_file_name = file
        
        
        #check all *c,*.cpp,*.cu
        # replace the kernel invoke kernel<<<...>>>
        if re.search( r'(.*\.cu)|(.*\.c)|(.*\.cpp)', file):
             #print(file)    
            # rw
            # store the file
            nlines = []
            with open(file,"r") as srcs:
                lines = srcs.readlines()
                for line in lines:
                    
                    if re.search(r"#include <kernel_copy.h>",line):
                        changed_file=True
                    
                    # tnis file haven't been modified yet
                    if changed_file==False:
                        #print(line)
                        if re.search( r'<<<', line):
                            # fine this kernel invoke
                            #print(line)
                            #line = line.strip('\n')
                            
                            # run the kernel multipul times
                            # defined in /usr/include/kernel_copy.h
                            # in case the makefile stay the same
                            include   ='    #include <kernel_copy.h>   \n'
                            wrap_begin='    wrapper_kernel_begin    \n'
                            wrap_end  ='    wrapper_kernel_end    \n'
                            newline   =include+wrap_begin+line+wrap_end+'\n'
                            #print(newline)
                            nlines.append(newline)
                        else:
                            nlines.append(line)
                        # the original file will be shadow    
                        new_file_name=ori_file_name.replace(".c",".bp")
                        generate_new_filer=True
                        
            # only when generating new file            
            if generate_new_file==True:
                os.rename(ori_file_name,new_file_name)
                with open(ori_file_name,"w") as newf:
                    newf.writelines(nlines)
#============================================================================================================
# do modification to the source code
#============================================================================================================

def modifySource():
    copy_cuda_kernels()

    
def do_shell_command(cmd):
    command=(str(cmd))
    print (command)
    subprocess.call(command, shell=True)
    
def profile_cuda_bin(binary_dir):
    with cd(bench_dir):


# bench_dir is the main dir of benchmark like Rodinia/  CUDASDK/
# the function will do the following things according to the params:
#  1. cd bench_dir
#  2. make clean
#  3. cd sec_bench_dir
#  4. for bench in sec_bench_dir: 
#         cd bench ; make
# for example , the dir structure of CUDA SDK is :
#  CUDASDK
#     |-----0_Simple
#             |--------aysncAPI/
#             |--------...
# so   sec_bench_dir is 0_Simple/ here , this can be read from the bench file
# make_benchmarks("./CUDASDK_bench.txt","Benchmark-Collection/CUDASDK","CUDA SDK")
def make_benchmarks(bench_file,bench_dir,bench_name):
    print(bench_name+" Start")
   
    # how many programs are maked(or other jobs be done)
    done_num = 0
    # total job nums
    tot_num =0
    
    dir_pair ={}
    
    # a file include all the bench-dir in a benchmark
    sdk_file = bench_file
    dirs = open(sdk_file,"r")
    # read all the benchs located in 
    lines = dirs.readlines()
    
    main_dir = ""
    
    # for each bench 
    for line in lines:
        line = line.strip('\n')
        line = line.replace(' ', '')
        # sepecify main dir
        #print(line)
        
        # the first line is an identification to which benchmarks are working on
        # the format is '\d'_xxxx
        if(line[0].isdigit() and line[1]=='_'):
               
            # for Rodinia
            if line == '0_cuda_rodinia':
                # next step should be 'cd cuda'
                line='cuda'
            # for Polybench
            elif line== '0_poly_CUDA':
                #next step should be 'cd CUDA'
                line='CUDA'
            elif line=='0_gm_src':
                # as mentioned before
                line='gm_src'
                
            # the main_dir is the parent dir to all benchs
            # main_dir
            #    |----bench1/
            #            |-----xxx.cu
            #            |-----makefile
            #    |----bench2/
            # ......
            main_dir=line    
            dir_pair[main_dir]=[]
        else:
            # store the bench dirs
            dir_pair[main_dir].append(line)  
            tot_num = tot_num+1
            
    # do jobs to all benchmarks
    with cd(bench_dir):
        # use make clean from the toppest makefile 
        command= 'make clean'
        print('\n' + command)
        subprocess.call(command, shell=True)
        
        # deep into each bench dir
        for key in dir_pair:
            print('<<enter>> {}'.format(key))
            with cd('{}'.format(key)):
                    for bench in dir_pair[key]:
                        with cd('{}'.format(bench)):
                            # 1.something todo with the source file
                            modifySource()
                            # 2.make the program
                            do_shell_command('make')
                            # how many are done
                            done_num = done_num + 1
                            print('['+str(done_num)+'/'+str(tot_num)+']')
            print('<<leave>> {}'.format(key))
    #============================================================
    print(bench_name+" Done")
    

if __name__ == "__main__":
    make_benchmarks("./Poly_bench.txt"   ,"Polybench/"  ,"Polybench")
    #modifySource()
# Out:
# Polybench Start
#
# make clean
# cd CUDA ; ./clean.sh
# 2DCONV
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/2DCONV
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/2DCONV'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/2DCONV'
# 2MM
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/2MM
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/2MM'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/2MM'
# 3DCONV
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/3DCONV
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/3DCONV'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/3DCONV'
# 3MM
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/3MM
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/3MM'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/3MM'
# ATAX
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/ATAX
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/ATAX'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/ATAX'
# BICG
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/BICG
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/BICG'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/BICG'
# clean.sh
# common.mk
# CORR
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/CORR
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/CORR'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/CORR'
# COVAR
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/COVAR
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/COVAR'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/COVAR'
# FDTD-2D
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/FDTD-2D
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/FDTD-2D'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/FDTD-2D'
# GEMM
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GEMM
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GEMM'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GEMM'
# GESUMMV
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GESUMMV
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GESUMMV'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GESUMMV'
# GRAMSCHM
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GRAMSCHM
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GRAMSCHM'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/GRAMSCHM'
# make.sh
# MVT
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/MVT
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/MVT'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/MVT'
# SYR2K
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/SYR2K
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/SYR2K'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/SYR2K'
# SYRK
# /home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/SYRK
# make[1]: Entering directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/SYRK'
# rm -f *~ *.out *.exe
# make[1]: Leaving directory '/home/wwr/Desktop/ExperimentDataProcess/Polybench/CUDA/SYRK'
# <<enter>> CUDA
# [1/15]
# [2/15]
# [3/15]
# [4/15]
# [5/15]
# [6/15]
# [7/15]
# [8/15]
# [9/15]
# [10/15]
# [11/15]
# [12/15]
# [13/15]
# [14/15]
# [15/15]
# <<leave>> CUDA
# Polybench Done
